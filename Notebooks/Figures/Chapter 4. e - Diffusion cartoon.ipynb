# %%
import json
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.signal import savgol_filter, find_peaks
from matplotlib import cm
from matplotlib.colors import ListedColormap

# %%
plt.figure(figsize=(10, 2))
#jet = cm.get_cmap('viridis')
jet = cm.get_cmap('jet')
red_color = jet(1.0)
red_cmap = ListedColormap([red_color])
data = np.random.rand(10, 10)
plt.xticks([])
plt.yticks([])
plt.imshow(data, cmap=red_cmap, aspect='auto')
plt.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.savefig('1_full_nutrients.png',dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_6182/2292263725.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap('jet')

# %%
plt.figure(figsize=(10,2))

xq = np.linspace(0, 1, 12)
yq = np.linspace(0, 1, 6)
Xq, Yq = np.meshgrid(xq, yq)

x = np.linspace(0, 1, 1000)  
y = np.linspace(0, 1, 1000)

X, Y = np.meshgrid(x, y)

# for jet
shift = 1.7
# for viridis
#shift = 1.5
Zq = (Xq**2 + Yq**2)
Z = X**2 + Y**2 + shift

dx, dy = np.gradient(Zq)

#plt.imshow(Z, extent=[0, 1, 0, 1], origin='upper', aspect='auto',vmin=0, vmax=2)
plt.imshow(Z, extent=[0, 1, 0, 1], origin='upper', cmap='jet', aspect='auto',vmin=0, vmax=2)
#plt.colorbar()
plt.quiver(Xq, Yq, -dx, dy, color='black',width=0.003,headwidth=3,headlength=5,headaxislength=4.5)
plt.xticks([])
plt.yticks([])

plt.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.savefig('2_gradient.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(10,2))

xq = np.linspace(0, 1, 12)
yq = np.linspace(0, 1, 6)
Xq, Yq = np.meshgrid(xq, yq)

x = np.linspace(0, 1, 1000)  
y = np.linspace(0, 1, 1000)

X, Y = np.meshgrid(x, y)

# for jet
shift = 1
# for viridis
#shift = 1

Zq = Xq**2 + Yq**2
Z = X**2 + Y**2 + shift

dx, dy = np.gradient(Zq)
#plt.imshow(Z, extent=[0, 1, 0, 1], origin='upper', aspect='auto',vmin=0, vmax=2)
plt.imshow(Z, extent=[0, 1, 0, 1], origin='upper', cmap='jet', aspect='auto',vmin=0, vmax=2)
#plt.colorbar()
plt.quiver(Xq, Yq, -dx, dy, color='black',width=0.003,headwidth=3,headlength=5,headaxislength=4.5)
plt.xticks([])
plt.yticks([])

plt.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.savefig('3_gradient.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(10,2))

xq = np.linspace(0, 1, 12)
yq = np.linspace(0, 1, 6)
Xq, Yq = np.meshgrid(xq, yq)

x = np.linspace(0, 1, 1000)  
y = np.linspace(0, 1, 1000)

X, Y = np.meshgrid(x, y)

# for jet
shift = 1.4

# for viridis
#shift = 1.4

Zq = Xq**2 + Yq**2
Z = X**2 + Y**2 + shift

dx, dy = np.gradient(Zq)
#plt.imshow(Z, extent=[0, 1, 0, 1], origin='upper', aspect='auto',vmin=0, vmax=2)
plt.imshow(Z, extent=[0, 1, 0, 1], origin='upper', cmap='jet', aspect='auto',vmin=0, vmax=2)
#plt.colorbar()
plt.quiver(Xq, Yq, -dx, dy, color='black',width=0.003,headwidth=3,headlength=5,headaxislength=4.5)
plt.xticks([])
plt.yticks([])

plt.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.savefig('4_gradient.png',dpi=300)
plt.show()
